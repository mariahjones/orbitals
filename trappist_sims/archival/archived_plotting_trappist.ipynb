# %% [markdown]
# ### TRAPPIST-1b

# %%
import numpy as np
import rebound
import matplotlib.pyplot as plt

sa = rebound.Simulationarchive("trappist_1b.bin")

tmax = sa.tmax
tmin = sa.tmin
nshots = len(sa)  # number of snapshots

times = np.linspace(tmin, tmax, nshots)

# Lists to hold mean longitudes for Trappist-1b and its coorbitals
lambda_1b = []
lambda_coorb = [[] for _ in range(20)]  # There are 20 coorbitals
diff = [[] for _ in range(20)]  # Difference in mean longitude

# Load in each snapshot
for i in range(nshots):
    sim = sa[i]  # Get the simulation at snapshot i

    # Mean longitude for Trappist-1b
    lambda_1b.append(sim.particles[1].l)

    # Mean longitudes for coorbitals
    for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
        lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
        diff[j].append(sim.particles[j+6].l - sim.particles[1].l)  # Difference in mean longitude

# Number of coorbitals with data
num_coorbitals = sum(bool(data) for data in diff)

# Plot mean longitude differences with respect to time
fig, axs = plt.subplots(4, 5, figsize=(15, 9), sharex=True, sharey=True)
ymax = np.pi
ymin = -(np.pi)

for i in range(20):
    if diff[i]:
        row, col = divmod(i, 5)
        ax = axs[row, col]
        ax.plot(times, diff[i], marker='o', markersize=.5, linestyle='None', label=f'Coorbital {i}')
        ax.set_title(f'Coorbital {i}')
        ax.set_xlabel('Time')
        ax.set_ylabel(r'$\lambda_{\mathrm{coorbital}} - \lambda_{\mathrm{1b}}$')  # LaTeX formatted label
        ax.set_xlim(tmin, tmax)
        ax.set_ylim(ymin, ymax)

plt.tight_layout()
#plt.savefig('1b_mean_long.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# filenames = ["trappist_1b.bin","trappist_1c.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1b.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    eccentricities = []   # Store eccentricity values for Trappist-1b and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold eccentricity for the current snapshot
        ecc_snapshot = []

        for j in range(len(os)):
            ecc_snapshot.append(os[j].e)

        # Append the list of eccentricities for the current snapshot
        eccentricities.append(ecc_snapshot)

    # Plot eccentricity versus time for Trappist-1b and its co-orbitals
    eccentricities = np.array(eccentricities)
    plt.figure(figsize=(10, 6))
    plt.plot(times, eccentricities[:, 0], label='Trappist-1b')
    for j in range(7, 27):  # Indices 7-26 represent co-orbitals
        plt.plot(times, eccentricities[:, j], label=f'Co-orbital_{j-6}')  # Label starts from Co-orbital_1
    plt.xlabel('Time')
    plt.ylabel('Eccentricity')
    plt.title('Eccentricity of Trappist-1b and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1b_eccs.png')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import rebound

# filenames = ["trappist_1b.bin","trappist_1c.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1b.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    inclinations = []   # Store inclination values for Trappist-1b and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold inclination for the current snapshot
        inc_snapshot = []

        for j in range(len(os)):
            inc_snapshot.append(os[j].inc)

        # Append the list of inclinations for the current snapshot
        inclinations.append(inc_snapshot)

    # Plot inclination versus time for Trappist-1b and its co-orbitals
    inclinations = np.array(inclinations)
    plt.figure(figsize=(10, 6))
    plt.plot(times, inclinations[:, 0], label='Trappist-1b')
    for j in range(7, 27):
        plt.plot(times, inclinations[:, j], label=f'Co-orbital_{j-6}')  # chr(98)='b', chr(99)='c', ..., chr(104)='h'
    plt.xlabel('Time')
    plt.ylabel('Inclination (radians)')
    plt.title('Inclination of Trappist-1b and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1b_incs.png')
    plt.show()

# %% [markdown]
# ### TRAPPIST-1c

# %%
import numpy as np
import rebound
import matplotlib.pyplot as plt

sa = rebound.Simulationarchive("trappist_1c.bin")

tmax = sa.tmax
tmin = sa.tmin
nshots = len(sa)  # number of snapshots

times = np.linspace(tmin, tmax, nshots)

# Lists to hold mean longitudes for Trappist-1c and its coorbitals
lambda_1c = []
lambda_coorb = [[] for _ in range(20)]  # There are 20 coorbitals
diff = [[] for _ in range(20)]  # Difference in mean longitude

# Load in each snapshot
for i in range(nshots):
    sim = sa[i]  # Get the simulation at snapshot i

    # Mean longitude for Trappist-1c
    lambda_1c.append(sim.particles[2].l)

    # Mean longitudes for coorbitals
    for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
        lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
        diff[j].append(sim.particles[j+6].l - sim.particles[2].l)  # Difference in mean longitude

# Number of coorbitals with data
num_coorbitals = sum(bool(data) for data in diff)

# Plot mean longitude differences with respect to time
fig, axs = plt.subplots(4, 5, figsize=(15, 9), sharex=True, sharey=True)
ymax = np.pi
ymin = -(np.pi)

for i in range(20):
    if diff[i]:
        row, col = divmod(i, 5)
        ax = axs[row, col]
        ax.plot(times, diff[i], marker='o', markersize=.5, linestyle='None', label=f'Coorbital {i}')
        ax.set_title(f'Coorbital {i}')
        ax.set_xlabel('Time')
        ax.set_ylabel(r'$\lambda_{\mathrm{coorbital}} - \lambda_{\mathrm{1c}}$')  # LaTeX formatted label
        ax.set_xlim(tmin, tmax)
        ax.set_ylim(ymin, ymax)

plt.tight_layout()
#plt.savefig('1c_mean_long.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# filenames = ["trappist_1c.bin","trappist_1c.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1c.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    eccentricities = []   # Store eccentricity values for Trappist-1c and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold eccentricity for the current snapshot
        ecc_snapshot = []

        for j in range(len(os)):
            ecc_snapshot.append(os[j].e)

        # Append the list of eccentricities for the current snapshot
        eccentricities.append(ecc_snapshot)

    # Plot eccentricity versus time for Trappist-1c and its co-orbitals
    eccentricities = np.array(eccentricities)
    plt.figure(figsize=(10, 6))
    plt.plot(times, eccentricities[:, 1], label='Trappist-1c')
    for j in range(7, 27):  # Indices 7-26 represent co-orbitals
        plt.plot(times, eccentricities[:, j], label=f'Co-orbital_{j-6}')  # Label starts from Co-orbital_1
    plt.xlabel('Time')
    plt.ylabel('Eccentricity')
    plt.title('Eccentricity of Trappist-1c and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1c_eccs.png')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import rebound

# filenames = ["trappist_1c.bin","trappist_1c.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1c.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    inclinations = []   # Store inclination values for Trappist-1c and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold inclination for the current snapshot
        inc_snapshot = []

        for j in range(len(os)):
            inc_snapshot.append(os[j].inc)

        # Append the list of inclinations for the current snapshot
        inclinations.append(inc_snapshot)

    # Plot inclination versus time for Trappist-1c and its co-orbitals
    inclinations = np.array(inclinations)
    plt.figure(figsize=(10, 6))
    plt.plot(times, inclinations[:, 1], label='Trappist-1c')
    for j in range(7, 27):
        plt.plot(times, inclinations[:, j], label=f'Co-orbital_{j-6}')  # chr(98)='b', chr(99)='c', ..., chr(104)='h'
    plt.xlabel('Time')
    plt.ylabel('Inclination (radians)')
    plt.title('Inclination of Trappist-1c and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1c_incs.png')
    plt.show()

# %% [markdown]
# ### TRAPPIST-1d

# %%
import numpy as np
import rebound
import matplotlib.pyplot as plt

sa = rebound.Simulationarchive("trappist_1d.bin")

tmax = sa.tmax
tmin = sa.tmin
nshots = len(sa)  # number of snapshots

times = np.linspace(tmin, tmax, nshots)

# Lists to hold mean longitudes for Trappist-1d and its coorbitals
lambda_1d = []
lambda_coorb = [[] for _ in range(20)]  # There are 20 coorbitals
diff = [[] for _ in range(20)]  # Difference in mean longitude

# Load in each snapshot
for i in range(nshots):
    sim = sa[i]  # Get the simulation at snapshot i

    # Mean longitude for Trappist-1d
    lambda_1d.append(sim.particles[3].l)

    # Mean longitudes for coorbitals
    for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
        lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
        diff[j].append(sim.particles[j+6].l - sim.particles[3].l)  # Difference in mean longitude

# Number of coorbitals with data
num_coorbitals = sum(bool(data) for data in diff)

# Plot mean longitude differences with respect to time
fig, axs = plt.subplots(4, 5, figsize=(15, 9), sharex=True, sharey=True)
ymax = np.pi
ymin = -(np.pi)

for i in range(20):
    if diff[i]:
        row, col = divmod(i, 5)
        ax = axs[row, col]
        ax.plot(times, diff[i], marker='o', markersize=.5, linestyle='None', label=f'Coorbital {i}')
        ax.set_title(f'Coorbital {i}')
        ax.set_xlabel('Time')
        ax.set_ylabel(r'$\lambda_{\mathrm{coorbital}} - \lambda_{\mathrm{1d}}$')  # LaTeX formatted label
        ax.set_xlim(tmin, tmax)
        ax.set_ylim(ymin, ymax)

plt.tight_layout()
#plt.savefig('1d_mean_long.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 27
#      25     # Mean longitudes for coorbitals
#      26     for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
# ---> 27         lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
#      28         diff[j].append(sim.particles[j+6].l - sim.particles[3].l)  # Difference in mean longitude
#      30 # Number of coorbitals with data
#
# File ~/anaconda3/lib/python3.11/site-packages/rebound/particles.py:46, in Particles.__getitem__(self, key)
#      44         key += self.sim.N
#      45     if key < 0 or key >= self.sim.N:
# ---> 46         raise AttributeError("Index {0} used to access particles out of range.".format(key))
#      47     return self._ps[key]
#      49 else:
#
# AttributeError: Index 21 used to access particles out of range.

# %%
import numpy as np
import matplotlib.pyplot as plt

# filenames = ["trappist_1d.bin","trappist_1d.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1d.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    eccentricities = []   # Store eccentricity values for Trappist-1d and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold eccentricity for the current snapshot
        ecc_snapshot = []

        for j in range(len(os)):
            ecc_snapshot.append(os[j].e)

        # Append the list of eccentricities for the current snapshot
        eccentricities.append(ecc_snapshot)

    # Plot eccentricity versus time for Trappist-1d and its co-orbitals
    eccentricities = np.array(eccentricities)
    plt.figure(figsize=(10, 6))
    plt.plot(times, eccentricities[:, 2], label='Trappist-1d')
    for j in range(7, 27):  # Indices 7-26 represent co-orbitals
        plt.plot(times, eccentricities[:, j], label=f'Co-orbital_{j-6}')  # Label starts from Co-orbital_1
    plt.xlabel('Time')
    plt.ylabel('Eccentricity')
    plt.title('Eccentricity of Trappist-1d and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1d_eccs.png')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import rebound

# filenames = ["trappist_1d.bin","trappist_1d.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1d.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    inclinations = []   # Store inclination values for Trappist-1d and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold inclination for the current snapshot
        inc_snapshot = []

        for j in range(len(os)):
            inc_snapshot.append(os[j].inc)

        # Append the list of inclinations for the current snapshot
        inclinations.append(inc_snapshot)

    # Plot inclination versus time for Trappist-1d and its co-orbitals
    inclinations = np.array(inclinations)
    plt.figure(figsize=(10, 6))
    plt.plot(times, inclinations[:, 2], label='Trappist-1d')
    for j in range(7, 27):
        plt.plot(times, inclinations[:, j], label=f'Co-orbital_{j-6}')  # chr(98)='b', chr(99)='c', ..., chr(104)='h'
    plt.xlabel('Time')
    plt.ylabel('Inclination (radians)')
    plt.title('Inclination of Trappist-1d and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1d_incs.png')
    plt.show()

# %% [markdown]
# ### TRAPPIST-1e

# %%
import numpy as np
import rebound
import matplotlib.pyplot as plt

sa = rebound.Simulationarchive("trappist_1e.bin")

tmax = sa.tmax
tmin = sa.tmin
nshots = len(sa)  # number of snapshots

times = np.linspace(tmin, tmax, nshots)

# Lists to hold mean longitudes for Trappist-1e and its coorbitals
lambda_1e = []
lambda_coorb = [[] for _ in range(20)]  # There are 20 coorbitals
diff = [[] for _ in range(20)]  # Difference in mean longitude

# Load in each snapshot
for i in range(nshots):
    sim = sa[i]  # Get the simulation at snapshot i

    # Mean longitude for Trappist-1e
    lambda_1e.append(sim.particles[4].l)

    # Mean longitudes for coorbitals
    for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
        lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
        diff[j].append(sim.particles[j+6].l - sim.particles[4].l)  # Difference in mean longitude

# Number of coorbitals with data
num_coorbitals = sum(bool(data) for data in diff)

# Plot mean longitude differences with respect to time
fig, axs = plt.subplots(4, 5, figsize=(15, 9), sharex=True, sharey=True)
ymax = np.pi
ymin = -(np.pi)

for i in range(20):
    if diff[i]:
        row, col = divmod(i, 5)
        ax = axs[row, col]
        ax.plot(times, diff[i], marker='o', markersize=.5, linestyle='None', label=f'Coorbital {i}')
        ax.set_title(f'Coorbital {i}')
        ax.set_xlabel('Time')
        ax.set_ylabel(r'$\lambda_{\mathrm{coorbital}} - \lambda_{\mathrm{1e}}$')  # LaTeX formatted label
        ax.set_xlim(tmin, tmax)
        ax.set_ylim(ymin, ymax)

plt.tight_layout()
#plt.savefig('1e_mean_long.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# filenames = ["trappist_1e.bin","trappist_1e.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1e.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    eccentricities = []   # Store eccentricity values for Trappist-1e and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold eccentricity for the current snapshot
        ecc_snapshot = []

        for j in range(len(os)):
            ecc_snapshot.append(os[j].e)

        # Append the list of eccentricities for the current snapshot
        eccentricities.append(ecc_snapshot)

    # Plot eccentricity versus time for Trappist-1e and its co-orbitals
    eccentricities = np.array(eccentricities)
    plt.figure(figsize=(10, 6))
    plt.plot(times, eccentricities[:, 3], label='Trappist-1e')
    for j in range(7, 27):  # Indices 7-26 represent co-orbitals
        plt.plot(times, eccentricities[:, j], label=f'Co-orbital_{j-6}')  # Label starts from Co-orbital_1
    plt.xlabel('Time')
    plt.ylabel('Eccentricity')
    plt.title('Eccentricity of Trappist-1e and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1e_eccs.png')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import rebound

# filenames = ["trappist_1e.bin","trappist_1e.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1e.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    inclinations = []   # Store inclination values for Trappist-1e and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold inclination for the current snapshot
        inc_snapshot = []

        for j in range(len(os)):
            inc_snapshot.append(os[j].inc)

        # Append the list of inclinations for the current snapshot
        inclinations.append(inc_snapshot)

    # Plot inclination versus time for Trappist-1e and its co-orbitals
    inclinations = np.array(inclinations)
    plt.figure(figsize=(10, 6))
    plt.plot(times, inclinations[:, 3], label='Trappist-1e')
    for j in range(7, 27):
        plt.plot(times, inclinations[:, j], label=f'Co-orbital_{j-6}')  # chr(98)='b', chr(99)='c', ..., chr(104)='h'
    plt.xlabel('Time')
    plt.ylabel('Inclination (radians)')
    plt.title('Inclination of Trappist-1e and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1e_incs.png')
    plt.show()

# %% [markdown]
# ### TRAPPIST-1f

# %%
import numpy as np
import rebound
import matplotlib.pyplot as plt

sa = rebound.Simulationarchive("trappist_1f.bin")

tmax = sa.tmax
tmin = sa.tmin
nshots = len(sa)  # number of snapshots

times = np.linspace(tmin, tmax, nshots)

# Lists to hold mean longitudes for Trappist-1f and its coorbitals
lambda_1f = []
lambda_coorb = [[] for _ in range(20)]  # There are 20 coorbitals
diff = [[] for _ in range(20)]  # Difference in mean longitude

# Load in each snapshot
for i in range(nshots):
    sim = sa[i]  # Get the simulation at snapshot i

    # Mean longitude for Trappist-1f
    lambda_1f.append(sim.particles[5].l)

    # Mean longitudes for coorbitals
    for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
        lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
        diff[j].append(sim.particles[j+6].l - sim.particles[5].l)  # Difference in mean longitude

# Number of coorbitals with data
num_coorbitals = sum(bool(data) for data in diff)

# Plot mean longitude differences with respect to time
fig, axs = plt.subplots(4, 5, figsize=(15, 9), sharex=True, sharey=True)
ymax = np.pi
ymin = -(np.pi)

for i in range(20):
    if diff[i]:
        row, col = divmod(i, 5)
        ax = axs[row, col]
        ax.plot(times, diff[i], marker='o', markersize=.5, linestyle='None', label=f'Coorbital {i}')
        ax.set_title(f'Coorbital {i}')
        ax.set_xlabel('Time')
        ax.set_ylabel(r'$\lambda_{\mathrm{coorbital}} - \lambda_{\mathrm{1f}}$')  # LaTeX formatted label
        ax.set_xlim(tmin, tmax)
        ax.set_ylim(ymin, ymax)

plt.tight_layout()
#plt.savefig('1f_mean_long.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# filenames = ["trappist_1f.bin","trappist_1f.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1f.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    eccentricities = []   # Store eccentricity values for Trappist-1f and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold eccentricity for the current snapshot
        ecc_snapshot = []

        for j in range(len(os)):
            ecc_snapshot.append(os[j].e)

        # Append the list of eccentricities for the current snapshot
        eccentricities.append(ecc_snapshot)

    # Plot eccentricity versus time for Trappist-1f and its co-orbitals
    eccentricities = np.array(eccentricities)
    plt.figure(figsize=(10, 6))
    plt.plot(times, eccentricities[:, 4], label='Trappist-1f')
    for j in range(7, 27):  # Indices 7-26 represent co-orbitals
        plt.plot(times, eccentricities[:, j], label=f'Co-orbital_{j-6}')  # Label starts from Co-orbital_1
    plt.xlabel('Time')
    plt.ylabel('Eccentricity')
    plt.title('Eccentricity of Trappist-1f and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1f_eccs.png')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import rebound

# filenames = ["trappist_1f.bin","trappist_1f.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1f.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    inclinations = []   # Store inclination values for Trappist-1f and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold inclination for the current snapshot
        inc_snapshot = []

        for j in range(len(os)):
            inc_snapshot.append(os[j].inc)

        # Append the list of inclinations for the current snapshot
        inclinations.append(inc_snapshot)

    # Plot inclination versus time for Trappist-1f and its co-orbitals
    inclinations = np.array(inclinations)
    plt.figure(figsize=(10, 6))
    plt.plot(times, inclinations[:, 4], label='Trappist-1f')
    for j in range(7, 27):
        plt.plot(times, inclinations[:, j], label=f'Co-orbital_{j-6}')  # chr(98)='b', chr(99)='c', ..., chr(104)='h'
    plt.xlabel('Time')
    plt.ylabel('Inclination (radians)')
    plt.title('Inclination of Trappist-1f and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1f_incs.png')
    plt.show()

# %% [markdown]
# ### TRAPPIST-1g

# %%
import numpy as np
import rebound
import matplotlib.pyplot as plt

sa = rebound.Simulationarchive("trappist_1g.bin")

tmax = sa.tmax
tmin = sa.tmin
nshots = len(sa)  # number of snapshots

times = np.linspace(tmin, tmax, nshots)

# Lists to hold mean longitudes for Trappist-1g and its coorbitals
lambda_1g = []
lambda_coorb = [[] for _ in range(20)]  # There are 20 coorbitals
diff = [[] for _ in range(20)]  # Difference in mean longitude

# Load in each snapshot
for i in range(nshots):
    sim = sa[i]  # Get the simulation at snapshot i

    # Mean longitude for Trappist-1g
    lambda_1g.append(sim.particles[6].l)

    # Mean longitudes for coorbitals
    for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
        lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
        diff[j].append(sim.particles[j+6].l - sim.particles[6].l)  # Difference in mean longitude

# Number of coorbitals with data
num_coorbitals = sum(bool(data) for data in diff)

# Plot mean longitude differences with respect to time
fig, axs = plt.subplots(4, 5, figsize=(15, 9), sharex=True, sharey=True)
ymax = np.pi
ymin = -(np.pi)

for i in range(20):
    if diff[i]:
        row, col = divmod(i, 5)
        ax = axs[row, col]
        ax.plot(times, diff[i], marker='o', markersize=.5, linestyle='None', label=f'Coorbital {i}')
        ax.set_title(f'Coorbital {i}')
        ax.set_xlabel('Time')
        ax.set_ylabel(r'$\lambda_{\mathrm{coorbital}} - \lambda_{\mathrm{1g}}$')  # LaTeX formatted label
        ax.set_xlim(tmin, tmax)
        ax.set_ylim(ymin, ymax)

plt.tight_layout()
#plt.savefig('1g_mean_long.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# filenames = ["trappist_1g.bin","trappist_1g.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1g.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    eccentricities = []   # Store eccentricity values for Trappist-1g and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold eccentricity for the current snapshot
        ecc_snapshot = []

        for j in range(len(os)):
            ecc_snapshot.append(os[j].e)

        # Append the list of eccentricities for the current snapshot
        eccentricities.append(ecc_snapshot)

    # Plot eccentricity versus time for Trappist-1g and its co-orbitals
    eccentricities = np.array(eccentricities)
    plt.figure(figsize=(10, 6))
    plt.plot(times, eccentricities[:, 5], label='Trappist-1g')
    for j in range(7, 27):  # Indices 7-26 represent co-orbitals
        plt.plot(times, eccentricities[:, j], label=f'Co-orbital_{j-6}')  # Label starts from Co-orbital_1
    plt.xlabel('Time')
    plt.ylabel('Eccentricity')
    plt.title('Eccentricity of Trappist-1g and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1g_eccs.png')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import rebound

# filenames = ["trappist_1g.bin","trappist_1g.bin","trappist_1d.bin","trappist_1e.bin","trappist_1f.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1g.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    inclinations = []   # Store inclination values for Trappist-1g and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold inclination for the current snapshot
        inc_snapshot = []

        for j in range(len(os)):
            inc_snapshot.append(os[j].inc)

        # Append the list of inclinations for the current snapshot
        inclinations.append(inc_snapshot)

    # Plot inclination versus time for Trappist-1g and its co-orbitals
    inclinations = np.array(inclinations)
    plt.figure(figsize=(10, 6))
    plt.plot(times, inclinations[:, 5], label='Trappist-1g')
    for j in range(7, 27):
        plt.plot(times, inclinations[:, j], label=f'Co-orbital_{j-6}')  # chr(98)='b', chr(99)='c', ..., chr(104)='h'
    plt.xlabel('Time')
    plt.ylabel('Inclination (radians)')
    plt.title('Inclination of Trappist-1g and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1g_incs.png')
    plt.show()

# %% [markdown]
# ### TRAPPIST-1h

# %%
import numpy as np
import rebound
import matplotlib.pyplot as plt

sa = rebound.Simulationarchive("trappist_1h.bin")

tmax = sa.tmax
tmin = sa.tmin
nshots = len(sa)  # number of snapshots

times = np.linspace(tmin, tmax, nshots)

# Lists to hold mean longitudes for Trappist-1h and its coorbitals
lambda_1h = []
lambda_coorb = [[] for _ in range(20)]  # There are 20 coorbitals
diff = [[] for _ in range(20)]  # Difference in mean longitude

# Load in each snapshot
for i in range(nshots):
    sim = sa[i]  # Get the simulation at snapshot i

    # Mean longitude for Trappist-1h
    lambda_1h.append(sim.particles[7].l)

    # Mean longitudes for coorbitals
    for j in range(20):  # Indices 7-26 (inclusive) are for coorbitals
        lambda_coorb[j].append(sim.particles[j+6].l)  # Coorbitals start from index 7 (6+1)
        diff[j].append(sim.particles[j+6].l - sim.particles[7].l)  # Difference in mean longitude

# Number of coorbitals with data
num_coorbitals = sum(bool(data) for data in diff)

# Plot mean longitude differences with respect to time
fig, axs = plt.subplots(4, 5, figsize=(15, 9), sharex=True, sharey=True)
ymax = np.pi
ymin = -(np.pi)

for i in range(20):
    if diff[i]:
        row, col = divmod(i, 5)
        ax = axs[row, col]
        ax.plot(times, diff[i], marker='o', markersize=.5, linestyle='None', label=f'Coorbital {i}')
        ax.set_title(f'Coorbital {i}')
        ax.set_xlabel('Time')
        ax.set_ylabel(r'$\lambda_{\mathrm{coorbital}} - \lambda_{\mathrm{1h}}$')  # LaTeX formatted label
        ax.set_xlim(tmin, tmax)
        ax.set_ylim(ymin, ymax)

plt.tight_layout()
#plt.savefig('1h_mean_long.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# filenames = ["trappist_1h.bin","trappist_1h.bin","trappist_1d.bin","trappist_1e.bin","trappist_1h.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1h.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    eccentricities = []   # Store eccentricity values for Trappist-1h and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold eccentricity for the current snapshot
        ecc_snapshot = []

        for j in range(len(os)):
            ecc_snapshot.append(os[j].e)

        # Append the list of eccentricities for the current snapshot
        eccentricities.append(ecc_snapshot)

    # Plot eccentricity versus time for Trappist-1h and its co-orbitals
    eccentricities = np.array(eccentricities)
    plt.figure(figsize=(10, 6))
    plt.plot(times, eccentricities[:, 6], label='Trappist-1h')
    for j in range(7, 27):  # Indices 7-26 represent co-orbitals
        plt.plot(times, eccentricities[:, j], label=f'Co-orbital_{j-6}')  # Label starts from Co-orbital_1
    plt.xlabel('Time')
    plt.ylabel('Eccentricity')
    plt.title('Eccentricity of Trappist-1h and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1h_eccs.png')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import rebound

# filenames = ["trappist_1h.bin","trappist_1h.bin","trappist_1d.bin","trappist_1e.bin","trappist_1h.bin","trappist_1g.bin","trappist_1h.bin"]
filenames = ["trappist_1h.bin"]

for filename in filenames:
    sa = rebound.Simulationarchive(filename)

    tmax = sa.tmax
    tmin = sa.tmin
    nshots = len(sa)  # number of snapshots

    times = np.linspace(tmin, tmax, nshots)

    inclinations = []   # Store inclination values for Trappist-1h and its co-orbitals

    # Load in each snapshot
    for i in range(nshots):
        ps = sa[i].particles  # particles at snapshot i
        os = sa[i].orbits()#  # orbits relative to the primary particle

        # List to hold inclination for the current snapshot
        inc_snapshot = []

        for j in range(len(os)):
            inc_snapshot.append(os[j].inc)

        # Append the list of inclinations for the current snapshot
        inclinations.append(inc_snapshot)

    # Plot inclination versus time for Trappist-1h and its co-orbitals
    inclinations = np.array(inclinations)
    plt.figure(figsize=(10, 6))
    plt.plot(times, inclinations[:, 6], label='Trappist-1h')
    for j in range(7, 27):
        plt.plot(times, inclinations[:, j], label=f'Co-orbital_{j-6}')  # chr(98)='b', chr(99)='c', ..., chr(104)='h'
    plt.xlabel('Time')
    plt.ylabel('Inclination (radians)')
    plt.title('Inclination of Trappist-1h and Co-orbitals')
    plt.legend(ncol=4)  # Set the number of columns in the legend
    #plt.savefig('1h_incs.png')
    plt.show()
